# %% [markdown]
# - spring break dates (february-April)
# - summer vacation dates (late May-September)
# - Thanksgiving Travel (End of November)
# - Christmas to New Years (End of December to Early Janurary)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
twentyone_tow_accidents = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\kristen_r_capstone\\data\\2021_tow_crashes.csv')

# %%
twentyone_tow_accidents.head()
# Out:
#        states  Bus (Seats for 9-15 People, including driver)  \
# 0     Alabama                                             19
# 1      Alaska                                              0
# 2     Arizona                                             23
# 3    Arkansas                                              8
# 4  California                                             15
#
#    Bus (Seats for > 15 People, including driver)  \
# 0                                             67
# 1                                              0
# 2                                             89
# 3                                             42
# 4                                            265
#
#   Single Unit Truck, 2 axle, 6 tire Single Unit Truck, 3+axle  \
# 0                               694                       320
# 1                                 2                         1
# 2                               154                       148
# ...

# %%
twentyone_injury_accidents = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\kristen_r_capstone\\data\\2021_injury_crashes.csv')

# %%
twentyone_injury_accidents.head()
# Out:
#    Unnamed: 0  Bus (Seats for 9-15 People, including driver)  \
# 0     Alabama                                             15
# 1      Alaska                                              0
# 2     Arizona                                              1
# 3    Arkansas                                              9
# 4  California                                             17
#
#    Bus (Seats for > 15 People, including driver)  \
# 0                                             27
# 1                                              0
# 2                                             15
# 3                                             41
# 4                                            309
#
#   Single Unit Truck, 2 axle, 6 tire  Single Unit Truck, 3+axle  \
# 0                               325                        187
# 1                                 1                          0
# 2                                28                         32
# ...

# %%
twentyone_fatal_accidents = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\kristen_r_capstone\\data\\2021_fatal_crashes.csv')

# %%
twentyone_fatal_accidents.head()
# Out:
#    Unnamed: 0  Bus (Seats for 9-15 People, including driver)  \
# 0     Alabama                                              3
# 1      Alaska                                              0
# 2     Arizona                                              3
# 3    Arkansas                                              0
# 4  California                                              2
#
#    Bus (Seats for > 15 People, including driver)  \
# 0                                              0
# 1                                              0
# 2                                              8
# 3                                              1
# 4                                             16
#
#    Single Unit Truck, 2 axle, 6 tire  Single Unit Truck, 3+axle  \
# 0                                 31                         10
# 1                                  0                          4
# 2                                 17                          6
# ...
