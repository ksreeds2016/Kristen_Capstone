# %% [markdown]
# - spring break dates (february-April)
# - summer vacation dates (late May-September)
# - Thanksgiving Travel (End of November)
# - Christmas to New Years (End of December to Early Janurary)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
total_acc_2022_by_month = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2022_month_crashes1.csv')

# %% [markdown]
# - No data for decemeber for total accidents by month
# - FMCSA Motor Carrier Management Information System (MCMIS) data snapshot as of 03/31/2023, including crash records through 11/30/2022

# %%
total_acc_2022_by_month.head()
# Out:
#         State January February  March  April    May   June   July August  \
# 0     Alabama     373      366    428    438    419    379    363    462
# 1      Alaska       4        2      2      0      2      0      1      2
# 2     Arizona     229      267    288    235    215    201    273    284
# 3    Arkansas     284      342    309    258    269    291    221    300
# 4  California   1,285    1,207  1,248  1,303  1,193  1,389  1,274  1,403
#
#   September October November  December   Total
# 0       387     429      396         0   4,440
# 1         1       0        0         0      14
# 2       247     219      249         0   2,707
# 3       267     303      248         0   3,092
# 4     1,345   1,332    1,248         0  14,227

# %%
total_acc_2022_by_month.dtypes
# Out:
# State        object
# January      object
# February     object
# March        object
# April        object
# May          object
# June         object
# July         object
# August       object
# September    object
# October      object
# November     object
# December      int64
# Total        object
# dtype: object

# %%
total_acc_2022_by_month = total_acc_2022_by_month.replace(',','', regex=True)

# %%
total_acc_2022_by_month.dtypes
# Out:
# State        object
# January      object
# February      int64
# March         int64
# April         int64
# May           int64
# June          int64
# July          int64
# August        int64
# September     int64
# October       int64
# November      int64
# December      int64
# Total         int64
# dtype: object

# %%
total_acc_2022_by_month[total_acc_2022_by_month.columns[2:]]=total_acc_2022_by_month[total_acc_2022_by_month.columns[2:]].replace(',','',regex=True).astype('int64')

# %%
total_acc_2021_by_month = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2021_all_crashes_month1.csv')

# %%
total_acc_2021_by_month.head()
# Out:
#         State January February  March  April    May   June   July August  \
# 0     Alabama     321      302    425    419    384    429    385    419
# 1      Alaska       1        2      3      0      1      0      1      0
# 2     Arizona     226      167    244    229    251    255    264    291
# 3    Arkansas     221      304    261    276    233    319    293    286
# 4  California   1,109    1,019  1,271  1,292  1,330  1,439  1,458  1,520
#
#   September October November December   Total
# 0       446     426      389      432   4,777
# 1         2       1        4        0      15
# 2       236     261      241      280   2,945
# 3       327     284      266      287   3,357
# 4     1,473   1,542    1,228    1,393  16,074

# %%
total_acc_2021_by_month[total_acc_2021_by_month.columns[2:]]=total_acc_2021_by_month[total_acc_2021_by_month.columns[2:]].replace(',','',regex=True).astype('int64')

# %%
total_acc_2021_by_month.dtypes
# Out:
# State        object
# January      object
# February      int64
# March         int64
# April         int64
# May           int64
# June          int64
# July          int64
# August        int64
# September     int64
# October       int64
# November      int64
# December      int64
# Total         int64
# dtype: object

# %%
total_acc_2020_by_month = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2020_all_crashes_month1.csv')

# %%
total_acc_2020_by_month
# Out:
#                 State January February   March  April     May    June    July  \
# 0             Alabama     385      371     353    256     313     354     360
# 1              Alaska       0        1       2      0       0       0       1
# 2             Arizona     177      169     189    141     168     211     155
# 3            Arkansas     256      206     235    193     205     230     275
# 4          California     962      926   1,014    749     868     987     989
# 5            Colorado     166      221     185    121     122     174     167
# 6         Connecticut     112       85     120     63      96     108      95
# 7            Delaware      57       54      47     34      27      48      60
# 8   Dist. Of Columbia      19       18      20     15      21      27      30
# 9             Florida     867      834     819    580     664     695     808
# 10            Georgia     513      524     523    373     382     462     472
# ...

# %%
total_acc_2020_by_month[total_acc_2020_by_month.columns[2:]]=total_acc_2020_by_month[total_acc_2020_by_month.columns[2:]].replace(',','',regex=True).astype('int64')

# %%
total_acc_2021_by_month.dtypes
# Out:
# State        object
# January      object
# February      int64
# March         int64
# April         int64
# May           int64
# June          int64
# July          int64
# August        int64
# September     int64
# October       int64
# November      int64
# December      int64
# Total         int64
# dtype: object
