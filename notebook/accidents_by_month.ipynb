# %% [markdown]
# - spring break dates (february-April)
# - summer vacation dates (late May-September)
# - Thanksgiving Travel (End of November)
# - Christmas to New Years (End of December to Early Janurary)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
total_acc_2022_by_month = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2022_month_crashes.csv')

# %% [markdown]
# - No data for decemeber for total accidents by month
# - FMCSA Motor Carrier Management Information System (MCMIS) data snapshot as of 03/31/2023, including crash records through 11/30/2022

# %%
total_acc_2022_by_month
# Out:
#            Unnamed: 0 January February  March  April    May   June   July  \
# 0             Alabama     373      366    428    438    419    379    363
# 1              Alaska       4        2      2      0      2      0      1
# 2             Arizona     229      267    288    235    215    201    273
# 3            Arkansas     284      342    309    258    269    291    221
# 4          California   1,285    1,207  1,248  1,303  1,193  1,389  1,274
# 5            Colorado     202      189    227    163    187    151    164
# 6         Connecticut     219      148    164    130    150    119    137
# 7            Delaware      49       45     62     57     79     48     47
# 8   Dist. Of Columbia      25       27     23      9     17     16     17
# 9             Florida     886      897  1,071    894    855    849    841
# 10            Georgia     592      555    568    571    563    583    434
# 11             Hawaii      12       10     17     13     14     15     17
# ...

# %% [markdown]
# DROP STATE COLUMN - NOT NEEDED FOR CURRENT ANALYSIS BASED OF ACCIDENTS BY MONTH

# %%
total_acc_2022_by_month = total_acc_2022_by_month.drop(columns = ['Unnamed: 0'])

# %%
total_acc_2022_by_month.head()
# Out:
#   January February  March  April    May   June   July August September  \
# 0     373      366    428    438    419    379    363    462       387
# 1       4        2      2      0      2      0      1      2         1
# 2     229      267    288    235    215    201    273    284       247
# 3     284      342    309    258    269    291    221    300       267
# 4   1,285    1,207  1,248  1,303  1,193  1,389  1,274  1,403     1,345
#
#   October November  December   Total
# 0     429      396         0   4,440
# 1       0        0         0      14
# 2     219      249         0   2,707
# 3     303      248         0   3,092
# 4   1,332    1,248         0  14,227

# %%
total_acc_2021_by_month = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2021_all_crashes_month.csv')

# %%
total_acc_2021_by_month.head()
# Out:
#    Unnamed: 0 January February  March  April    May   June   July August  \
# 0     Alabama     321      302    425    419    384    429    385    419
# 1      Alaska       1        2      3      0      1      0      1      0
# 2     Arizona     226      167    244    229    251    255    264    291
# 3    Arkansas     221      304    261    276    233    319    293    286
# 4  California   1,109    1,019  1,271  1,292  1,330  1,439  1,458  1,520
#
#   September October November December   Total
# 0       446     426      389      432   4,777
# 1         2       1        4        0      15
# 2       236     261      241      280   2,945
# 3       327     284      266      287   3,357
# 4     1,473   1,542    1,228    1,393  16,074

# %% [markdown]
# DROP STATE COLUMN - NOT NEEDED FOR CURRENT ANALYSIS BASED OF ACCIDENTS BY MONTH

# %%
total_acc_2021_by_month =total_acc_2021_by_month.drop(columns = ['Unnamed: 0'])

# %%
total_acc_2021_by_month.head()
# Out:
#   January February  March  April    May   June   July August September  \
# 0     321      302    425    419    384    429    385    419       446
# 1       1        2      3      0      1      0      1      0         2
# 2     226      167    244    229    251    255    264    291       236
# 3     221      304    261    276    233    319    293    286       327
# 4   1,109    1,019  1,271  1,292  1,330  1,439  1,458  1,520     1,473
#
#   October November December   Total
# 0     426      389      432   4,777
# 1       1        4        0      15
# 2     261      241      280   2,945
# 3     284      266      287   3,357
# 4   1,542    1,228    1,393  16,074

# %%
total_acc_2020_by_month = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2020_all_crashes_month.csv')

# %%
total_acc_2020_by_month
# Out:
#            Unnamed: 0 January February   March  April     May    June    July  \
# 0             Alabama     385      371     353    256     313     354     360
# 1              Alaska       0        1       2      0       0       0       1
# 2             Arizona     177      169     189    141     168     211     155
# 3            Arkansas     256      206     235    193     205     230     275
# 4          California     962      926   1,014    749     868     987     989
# 5            Colorado     166      221     185    121     122     174     167
# 6         Connecticut     112       85     120     63      96     108      95
# 7            Delaware      57       54      47     34      27      48      60
# 8   Dist. Of Columbia      19       18      20     15      21      27      30
# 9             Florida     867      834     819    580     664     695     808
# 10            Georgia     513      524     523    373     382     462     472
# ...

# %% [markdown]
# DROP STATE COLUMN - NOT NEEDED FOR CURRENT ANALYSIS BASED OF ACCIDENTS BY MONTH

# %%
total_acc_2020_by_month = total_acc_2020_by_month.drop(columns = ['Unnamed: 0', 'Total'])

# %%
total_acc_2020_by_month.head()
# Out:
#   January February  March April  May June July August September October  \
# 0     385      371    353   256  313  354  360    364       385     458
# 1       0        1      2     0    0    0    1      1         1       1
# 2     177      169    189   141  168  211  155    210       208     246
# 3     256      206    235   193  205  230  275    228       252     327
# 4     962      926  1,014   749  868  987  989  1,193     1,236   1,351
#
#   November December
# 0      443      377
# 1        0        5
# 2      219      217
# 3      228      217
# 4    1,153    1,185
