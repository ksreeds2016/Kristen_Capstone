# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# TOTAL ACCIDENTS IN 2022 BY MOTOR CARRIER

# %%
total_acc_2022 = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2022_all_accidents_by_mc1.csv')

# %%
total_acc_2022.head()
# Out:
#         State Bus (Seats for 9-15 People, including driver)  \
# 0     Alabama                                            26
# 1      Alaska                                             0
# 2     Arizona                                            32
# 3    Arkansas                                            13
# 4  California                                            42
#
#   Bus (Seats for > 15 People, including driver)  \
# 0                                           122
# 1                                             1
# 2                                           121
# 3                                            80
# 4                                           740
#
#   Single Unit Truck, 2 axle, 6 tire Single Unit Truck, 3+axle  \
# 0                             1,024                       416
# 1                                 4                         1
# 2                               220                       197
# ...

# %% [markdown]
# THE PROCESS OF CONVERTING "TOTAL" COLUMN FROM AND OBJ TO AN INT

# %%
total_acc_2022['Total']=total_acc_2022['Total'].str.replace(',','')

# %%
total_acc_2022['Total'] = total_acc_2022['Total'].astype(str).astype(int)

# %%
top_10_in_2022 = total_acc_2022.nlargest(10, "Total")

# %% [markdown]
# TOP 10 STATES WITH THE HIGHEST NUMBER OF ACCIDENTS IN 2022

# %%
top_10_in_2022
# Out:
#              State Bus (Seats for 9-15 People, including driver)  \
# 51       Sub Total                                         2,055
# 43           Texas                                           211
# 4       California                                            42
# 9          Florida                                           131
# 38    Pennsylvania                                            32
# 13        Illinois                                            58
# 32        New York                                           182
# 10         Georgia                                            42
# 33  North Carolina                                            11
# 25        Missouri                                           113
#
#    Bus (Seats for > 15 People, including driver)  \
# 51                                        11,592
# 43                                           868
# 4                                            740
# 9                                          1,001
# ...

# %% [markdown]
# TOTAL ACCIDENTS IN 2021 BY MOTOR CARRIER

# %%
total_acc_2021 = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2021_all_accidents_by_mc.csv')

# %%
total_acc_2021.head()
# Out:
#         State  Bus (Seats for 9-15 People, including driver)  \
# 0     Alabama                                             37
# 1      Alaska                                              0
# 2     Arizona                                             27
# 3    Arkansas                                             17
# 4  California                                             34
#
#   Bus (Seats for > 15 People, including driver)  \
# 0                                            94
# 1                                             0
# 2                                           112
# 3                                            84
# 4                                           590
#
#   Single Unit Truck, 2 axle, 6 tire Single Unit Truck, 3+axle  \
# 0                             1,050                       517
# 1                                 3                         5
# 2                               199                       186
# ...

# %% [markdown]
# THE PROCESS OF CONVERTING "TOTAL" COLUMN FROM AND OBJ TO AN INT

# %%
total_acc_2021['Total']=total_acc_2021['Total'].str.replace(',','')

# %%
total_acc_2021['Total'] = total_acc_2021['Total'].astype(str).astype(int)

# %% [markdown]
# TOP 10 STATES WITH THE HIGHEST NUMBER OF ACCIDENTS IN 2021

# %%
top_10_in_2021 = total_acc_2021.nlargest(10, "Total")

# %%
top_10_in_2021
# Out:
#              State  Bus (Seats for 9-15 People, including driver)  \
# 43           Texas                                            167
# 4       California                                             34
# 9          Florida                                            133
# 32        New York                                            159
# 13        Illinois                                             16
# 38    Pennsylvania                                             33
# 33  North Carolina                                              9
# 35            Ohio                                            469
# 10         Georgia                                             34
# 14         Indiana                                             33
#
#    Bus (Seats for > 15 People, including driver)  \
# 43                                           893
# 4                                            590
# 9                                          1,017
# ...

# %% [markdown]
# TOTAL ACCIDENTS IN 2020 BY MOTOR CARRIER

# %%
total_acc_2020 = pd.read_csv('C:\\Users\\ksree\\Documents\\dda9\\PYTHON\\PROJECTS\\Kristen_Capstone\\data\\2020_all_accidents_by_mc.csv')

# %%
total_acc_2020.head()
# Out:
#         State  Bus (Seats for 9-15 People, including driver)  \
# 0     Alabama                                             16
# 1      Alaska                                              0
# 2     Arizona                                             18
# 3    Arkansas                                             20
# 4  California                                             46
#
#    Bus (Seats for > 15 People, including driver)  \
# 0                                             92
# 1                                              0
# 2                                             88
# 3                                             77
# 4                                            379
#
#   Single Unit Truck, 2 axle, 6 tire Single Unit Truck, 3+axle  \
# 0                             1,000                       441
# 1                                 2                         1
# 2                               192                       295
# ...

# %% [markdown]
# THE PROCESS OF CONVERTING "TOTAL" COLUMN FROM AND OBJ TO AN INT

# %%
total_acc_2020['Total']=total_acc_2020['Total'].str.replace(',','')

# %%
total_acc_2020.dtypes
# Out:
# State                                            object
# Bus (Seats for 9-15 People, including driver)     int64
# Bus (Seats for > 15 People, including driver)     int64
# Single Unit Truck, 2 axle, 6 tire                object
# Single Unit Truck, 3+axle                        object
# Single Unit Truck, axles unknown                  int64
# Truck/Trailers                                   object
# Truck/Tractor (bobtail)                           int64
# Tractor/Semi-trailer                             object
# Tractor/Double                                    int64
# Tractor/Triple                                    int64
# Passenger Car, Only Displays HazMat Placard       int64
# Light Truck, Only Display HazMat Placard          int64
# Missing                                           int64
# Total                                            object
# dtype: object

# %%
total_acc_2020.head()
# Out:
#         State  Bus (Seats for 9-15 People, including driver)  \
# 0     Alabama                                             16
# 1      Alaska                                              0
# 2     Arizona                                             18
# 3    Arkansas                                             20
# 4  California                                             46
#
#    Bus (Seats for > 15 People, including driver)  \
# 0                                             92
# 1                                              0
# 2                                             88
# 3                                             77
# 4                                            379
#
#   Single Unit Truck, 2 axle, 6 tire Single Unit Truck, 3+axle  \
# 0                             1,000                       441
# 1                                 2                         1
# 2                               192                       295
# ...

# %%
total_acc_2020['Total'] = total_acc_2020['Total'].astype(str).astype(int)

# %%
top_10_in_2020 = total_acc_2020.nlargest(10, "Total")

# %% [markdown]
# TOP 10 STATES WITH THE HIGHEST NUMBER OF ACCIDENTS IN 2020

# %%
top_10_in_2020
# Out:
#              State  Bus (Seats for 9-15 People, including driver)  \
# 43           Texas                                            146
# 4       California                                             46
# 9          Florida                                            106
# 32        New York                                             74
# 33  North Carolina                                             17
# 38    Pennsylvania                                             18
# 13        Illinois                                             45
# 10         Georgia                                             25
# 35            Ohio                                            440
# 14         Indiana                                             30
#
#     Bus (Seats for > 15 People, including driver)  \
# 43                                            705
# 4                                             379
# 9                                             817
# ...
